# %% [markdown]
# # Use read_csv and skiprows with condition based on values in Pandas
#
# https://datascientyst.com/read_csv-skip-rows-condition-values-pandas/

# %%
import pandas as pd
csv_file = '../data/StudentsPerformance.csv'
df = pd.read_csv(csv_file)
print(df.shape)
df
# Out:
# (1000, 8)
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Step 1: Read CSV file skip rows with query condition

# %%
gen = pd.read_csv(csv_file, chunksize=10000000)
df = pd.concat((x.query("lunch == 'standard'") for x in gen), ignore_index=True)
df
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 3      male        group C                some college  standard
# 4    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 640    male        group E            some high school  standard
# 641  female        group B            some high school  standard
# 642    male        group A                 high school  standard
# 643  female        group E             master's degree  standard
# 644  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          76             78             75
# 4                      none          71             83             78
# ..                      ...         ...            ...            ...
# 640               completed          81             75             76
# 641               completed          65             82             78
# 642                    none          63             63             62
# 643               completed          88             99             95
# 644               completed          68             78             77
#
# [645 rows x 8 columns]

# %% [markdown]
# ## Step 2: Read CSV file with condition value higher than treshold

# %%
schema={
    "math score": int
}
gen = pd.read_csv(csv_file, dtype=schema, chunksize=10000000)
df = pd.concat((x.query("`math score` >= 75") for x in gen), ignore_index=True)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B             master's degree      standard
# 1      male        group C                some college      standard
# 2    female        group B                some college      standard
# 3      male        group A                some college      standard
# 4      male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 290  female        group A                some college      standard
# 291    male        group E            some high school      standard
# 292    male        group E                 high school  free/reduced
# 293  female        group E             master's degree      standard
# 294  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          90             95             93
# 1                      none          76             78             75
# 2                 completed          88             95             92
# 3                 completed          78             72             70
# 4                      none          88             89             86
# ..                      ...         ...            ...            ...
# 290               completed          78             87             91
# 291               completed          81             75             76
# 292               completed          86             81             75
# 293               completed          88             99             95
# 294                    none          77             86             86
#
# [295 rows x 8 columns]

# %% [markdown]
# ## Step 3: Read CSV file and post filter condition

# %%
df = pd.read_csv(csv_file)

df = df[df['lunch'] != 'standard']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# 7                      none          40             43             39
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 17                     none          18             32             28
# ..                      ...         ...            ...            ...
# 992                    none          55             76             76
# 993                    none          62             72             74
# 996                    none          62             55             55
# 997               completed          59             71             65
# 999                    none          77             86             86
#
# [355 rows x 8 columns]

# %% [markdown]
# ## Step 4: Read CSV with conditional filtering by Dask

# %%
import dask.dataframe as dd

df = dd.read_csv(csv_file)

df = df[(df['reading score'] >= 55) & (df['reading score'] <= 75)]

df = df.compute()
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 13     male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 987    male        group E            some high school      standard
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 3                      none          47             57             44
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 13                completed          78             72             70
# ..                      ...         ...            ...            ...
# 987               completed          81             75             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 996                    none          62             55             55
# 997               completed          59             71             65
#
# [496 rows x 8 columns]
