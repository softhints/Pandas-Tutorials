# %% [markdown]
# # Read Excel(OpenDocument ODS)  with Python Pandas
#
# Install library:
#
# ```python
# pip install odfpy
# ```

# %%
import pandas as pd

pd.read_excel('animals.ods')
# Out:
#    Rank                           Animal  \
# 0     1                 Peregrine falcon
# 1     2                     Golden eagle
# 2     3  White-throated needletail swift
# 3     4                   Eurasian hobby
# 4     5          Mexican free-tailed bat
# 5     6                      Frigatebird
# 6     7               Rock dove (pigeon)
# 7     8                Spur-winged goose
# 8     9                        Gyrfalcon
#
#                                        Maximum speed          Class  \
# 0         389 km/h (242 mph)108 m/s (354 ft/s)[2][6]  Flight-diving
# 1  240–320 km/h (150–200 mph)67–89 m/s (220–293 f...  Flight-diving
# 2                       169 km/h (105 mph)[8][9][10]         Flight
# 3                             160 km/h (100 mph)[11]         Flight
# 4                             160 km/h (100 mph)[12]         Flight
# 5                                  153 km/h (95 mph)         Flight
# 6                          148.9 km/h (92.5 mph)[13]         Flight
# ...

# %%
pd.read_excel('animals.ods', sheet_name="Sheet1")
# Out:
#    Rank                           Animal  \
# 0     1                 Peregrine falcon
# 1     2                     Golden eagle
# 2     3  White-throated needletail swift
# 3     4                   Eurasian hobby
# 4     5          Mexican free-tailed bat
# 5     6                      Frigatebird
# 6     7               Rock dove (pigeon)
# 7     8                Spur-winged goose
# 8     9                        Gyrfalcon
#
#                                        Maximum speed          Class  \
# 0         389 km/h (242 mph)108 m/s (354 ft/s)[2][6]  Flight-diving
# 1  240–320 km/h (150–200 mph)67–89 m/s (220–293 f...  Flight-diving
# 2                       169 km/h (105 mph)[8][9][10]         Flight
# 3                             160 km/h (100 mph)[11]         Flight
# 4                             160 km/h (100 mph)[12]         Flight
# 5                                  153 km/h (95 mph)         Flight
# 6                          148.9 km/h (92.5 mph)[13]         Flight
# ...

# %%
pd.read_excel('animals.ods', index_col=2)
# Out:
#                                                    Rank  \
# Maximum speed
# 389 km/h (242 mph)108 m/s (354 ft/s)[2][6]            1
# 240–320 km/h (150–200 mph)67–89 m/s (220–293 f...     2
# 169 km/h (105 mph)[8][9][10]                          3
# 160 km/h (100 mph)[11]                                4
# 160 km/h (100 mph)[12]                                5
# 153 km/h (95 mph)                                     6
# 148.9 km/h (92.5 mph)[13]                             7
# 142 km/h (88 mph)[14]                                 8
# 128 km/h (80 mph)[citation needed]                    9
#
#                                                                             Animal  \
# Maximum speed
# 389 km/h (242 mph)108 m/s (354 ft/s)[2][6]                        Peregrine falcon
# 240–320 km/h (150–200 mph)67–89 m/s (220–293 f...                     Golden eagle
# 169 km/h (105 mph)[8][9][10]                       White-throated needletail swift
# ...

# %%
pd.read_excel('animals.ods', usecols="A:C")
# Out:
#    Rank                           Animal  \
# 0     1                 Peregrine falcon
# 1     2                     Golden eagle
# 2     3  White-throated needletail swift
# 3     4                   Eurasian hobby
# 4     5          Mexican free-tailed bat
# 5     6                      Frigatebird
# 6     7               Rock dove (pigeon)
# 7     8                Spur-winged goose
# 8     9                        Gyrfalcon
#
#                                        Maximum speed
# 0         389 km/h (242 mph)108 m/s (354 ft/s)[2][6]
# 1  240–320 km/h (150–200 mph)67–89 m/s (220–293 f...
# 2                       169 km/h (105 mph)[8][9][10]
# 3                             160 km/h (100 mph)[11]
# 4                             160 km/h (100 mph)[12]
# 5                                  153 km/h (95 mph)
# 6                          148.9 km/h (92.5 mph)[13]
# 7                              142 km/h (88 mph)[14]
# 8                 128 km/h (80 mph)[citation needed]

# %%
pd.read_excel('animals.ods', index_col=2)
# Out:
#                                                    Rank  \
# Maximum speed
# 389 km/h (242 mph)108 m/s (354 ft/s)[2][6]            1
# 240–320 km/h (150–200 mph)67–89 m/s (220–293 f...     2
# 169 km/h (105 mph)[8][9][10]                          3
# 160 km/h (100 mph)[11]                                4
# 160 km/h (100 mph)[12]                                5
# 153 km/h (95 mph)                                     6
# 148.9 km/h (92.5 mph)[13]                             7
# 142 km/h (88 mph)[14]                                 8
# 128 km/h (80 mph)[citation needed]                    9
#
#                                                                             Animal  \
# Maximum speed
# 389 km/h (242 mph)108 m/s (354 ft/s)[2][6]                        Peregrine falcon
# 240–320 km/h (150–200 mph)67–89 m/s (220–293 f...                     Golden eagle
# 169 km/h (105 mph)[8][9][10]                       White-throated needletail swift
# ...

# %%
pd.read_excel('animals.ods', engine='odf')
# Out:
#    Rank                           Animal  \
# 0     1                 Peregrine falcon
# 1     2                     Golden eagle
# 2     3  White-throated needletail swift
# 3     4                   Eurasian hobby
# 4     5          Mexican free-tailed bat
# 5     6                      Frigatebird
# 6     7               Rock dove (pigeon)
# 7     8                Spur-winged goose
# 8     9                        Gyrfalcon
#
#                                        Maximum speed          Class  \
# 0         389 km/h (242 mph)108 m/s (354 ft/s)[2][6]  Flight-diving
# 1  240–320 km/h (150–200 mph)67–89 m/s (220–293 f...  Flight-diving
# 2                       169 km/h (105 mph)[8][9][10]         Flight
# 3                             160 km/h (100 mph)[11]         Flight
# 4                             160 km/h (100 mph)[12]         Flight
# 5                                  153 km/h (95 mph)         Flight
# 6                          148.9 km/h (92.5 mph)[13]         Flight
# ...
